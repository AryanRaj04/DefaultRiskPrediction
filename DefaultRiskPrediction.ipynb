# %%
import pandas as pd
import numpy as np

# %%
dt = pd.read_csv('vedika_final.csv')
dt.head()
# Out:
#    Unnamed: 0  SI No  Member No  Age  Gender Marital status  \
# 0           0      1  100022221   18  Female        Married
# 1           1      2  170022804   18  Female        Married
# 2           2      3  220022202   18  Female        Married
# 3           3      4  220022758   18  Female        Married
# 4           4      5  280022111   18  Female        Married
#
#   Educational level - literate/Illiterate  \
# 0                               Literate
# 1                             Illiterate
# 2                             Illiterate
# 3                             Illiterate
# 4                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
# ...

# %%
dt = dt.drop_duplicates(keep='last')

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10746 entries, 0 to 10745
# Data columns (total 21 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Unnamed: 0                                                       10746 non-null  int64
#  1   SI No                                                            10746 non-null  int64
#  2   Member No                                                        10746 non-null  int64
#  3   Age                                                              10746 non-null  int64
#  4   Gender                                                           10746 non-null  object
#  5   Marital status                                                   10746 non-null  object
#  6   Educational level - literate/Illiterate                          10746 non-null  object
# ...

# %%
dt.head()
# Out:
#    Unnamed: 0  SI No  Member No  Age  Gender Marital status  \
# 0           0      1  100022221   18  Female        Married
# 1           1      2  170022804   18  Female        Married
# 2           2      3  220022202   18  Female        Married
# 3           3      4  220022758   18  Female        Married
# 4           4      5  280022111   18  Female        Married
#
#   Educational level - literate/Illiterate  \
# 0                               Literate
# 1                             Illiterate
# 2                             Illiterate
# 3                             Illiterate
# 4                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
# ...

# %%
dt.drop(['SI No', 'Member No'], axis = 1, inplace = True)

# %%
dt.drop(['Spouse Employment  status - Employed/unemployed','Duration of credit'], axis = 1, inplace = True)
dt.head()
# Out:
#    Unnamed: 0  Age  Gender Marital status  \
# 0           0   18  Female        Married
# 1           1   18  Female        Married
# 2           2   18  Female        Married
# 3           3   18  Female        Married
# 4           4   18  Female        Married
#
#   Educational level - literate/Illiterate  \
# 0                               Literate
# 1                             Illiterate
# 2                             Illiterate
# 3                             Illiterate
# 4                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
#    Monthly Income Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# ...

# %%
dt.drop(['Gender', 'Marital status'], axis = 1, inplace = True)

# %%
dt.head()
# Out:
#    Unnamed: 0  Age Educational level - literate/Illiterate  \
# 0           0   18                               Literate
# 1           1   18                             Illiterate
# 2           2   18                             Illiterate
# 3           3   18                             Illiterate
# 4           4   18                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
#    Monthly Income Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0           15900                             Non-Farm          CONSTRUCTOR
# 1           15000                                 FARM                DAIRY
# ...

# %%
dt.drop(['No of dependent family members'], axis = 1, inplace = True)

# %%
dt.drop(['Employment status - Temporary/Permanent or Employed/Unemployed '], axis = 1, inplace = True)

# %%
dt.head()
# Out:
#    Unnamed: 0  Age Educational level - literate/Illiterate  Monthly Income  \
# 0           0   18                               Literate            15900
# 1           1   18                             Illiterate            15000
# 2           2   18                             Illiterate            19630
# 3           3   18                             Illiterate            12000
# 4           4   18                               Literate            15000
#
#   Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                             Non-Farm          CONSTRUCTOR
# 1                                 FARM                DAIRY
# 2                             Non-Farm               TAILOR
# 3                                 FARM              BUFFALO
# 4                             Non-Farm          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# ...

# %%
dt.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
dt.head()
# Out:
#    Age Educational level - literate/Illiterate  Monthly Income  \
# 0   18                               Literate            15900
# 1   18                             Illiterate            15000
# 2   18                             Illiterate            19630
# 3   18                             Illiterate            12000
# 4   18                               Literate            15000
#
#   Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                             Non-Farm          CONSTRUCTOR
# 1                                 FARM                DAIRY
# 2                             Non-Farm               TAILOR
# 3                                 FARM              BUFFALO
# 4                             Non-Farm          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
x = dt.drop(['Paid /Non Paid (Default)'], axis = 1)

# %%
y = dt['Paid /Non Paid (Default)']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x['Educational level - literate/Illiterate'] = le.fit_transform(x['Educational level - literate/Illiterate'])

# %%
dt.head()
# Out:
#    Age Educational level - literate/Illiterate  Monthly Income  \
# 0   18                               Literate            15900
# 1   18                             Illiterate            15000
# 2   18                             Illiterate            19630
# 3   18                             Illiterate            12000
# 4   18                               Literate            15000
#
#   Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                             Non-Farm          CONSTRUCTOR
# 1                                 FARM                DAIRY
# 2                             Non-Farm               TAILOR
# 3                                 FARM              BUFFALO
# 4                             Non-Farm          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
le2 = LabelEncoder()
x['Nature of livelihood - Farm/Non Farm'] = le2.fit_transform(x['Nature of livelihood - Farm/Non Farm'])

# %%
x.head()
# Out:
#    Age  Educational level - literate/Illiterate  Monthly Income  \
# 0   18                                        1           15900
# 1   18                                        0           15000
# 2   18                                        0           19630
# 3   18                                        0           12000
# 4   18                                        1           15000
#
#    Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                                     1          CONSTRUCTOR
# 1                                     0                DAIRY
# 2                                     1               TAILOR
# 3                                     0              BUFFALO
# 4                                     1          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
le3 = LabelEncoder()
y = le3.fit_transform(y)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
x['Monthly Income per family member'] = x['Monthly Income']/x['No of Family Members']

# %%
x.drop(['Monthly Income','No of Family Members'], axis = 1, inplace = True)

# %%
x.head()
# Out:
#    Age  Educational level - literate/Illiterate  \
# 0   18                                        1
# 1   18                                        0
# 2   18                                        0
# 3   18                                        0
# 4   18                                        1
#
#    Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                                     1          CONSTRUCTOR
# 1                                     0                DAIRY
# 2                                     1               TAILOR
# 3                                     0              BUFFALO
# 4                                     1          STOREKEEPER
#
#    No of years of affiliation with SHG  Amount of Arrear (Non-Repayment)   \
# 0                                    1                                  0
# 1                                    1                               1668
# 2                                    1                                  0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.2, random_state=42)

# %%
x['Sector of livelihood'].isna().sum()
# Out:
# 295

# %%
x_train['Sector of livelihood'].isna().sum()
# Out:
# 228

# %%
x_train['Sector of livelihood'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 10263    GROCERY VENDOR
# 8027           BUSINESS
# 6424           GARMENTS
# 3808              DAIRY
# 7093        STOREKEEPER
#               ...
# 10088       STOREKEEPER
# 2172              DAIRY
# 9281        STOREKEEPER
# 768            BUSINESS
# 10308    GROCERY VENDOR
# Name: Sector of livelihood, Length: 8596, dtype: object>

# %%
x_train['Sector of livelihood'].fillna(x_train['Sector of livelihood'].mode()[0], inplace = True)
# Out:
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
x_train['Sector of livelihood'].isna().sum()
# Out:
# 0

# %%
x_test['Sector of livelihood'].isna().sum()
# Out:
# 67

# %%
x_test['Sector of livelihood'].fillna(x_test['Sector of livelihood'].mode()[0], inplace = True)
x_test['Sector of livelihood'].isna().sum()
# Out:
# 0

# %%
x_train
# Out:
#        Age  Educational level - literate/Illiterate  \
# 10263   52                                        0
# 8027    43                                        1
# 6424    38                                        1
# 3808    32                                        0
# 7093    40                                        1
# ...    ...                                      ...
# 10088   51                                        1
# 2172    28                                        0
# 9281    47                                        0
# 768     23                                        0
# 10308   52                                        0
#
#        Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 10263                                     1       GROCERY VENDOR
# 8027                                      1             BUSINESS
# 6424                                      1             GARMENTS
# 3808                                      0                DAIRY
# ...

# %%
x_test
# Out:
#        Age  Educational level - literate/Illiterate  \
# 4799    34                                        1
# 6401    38                                        1
# 4245    33                                        1
# 5515    36                                        1
# 10316   52                                        0
# ...    ...                                      ...
# 2441    28                                        1
# 10617   56                                        1
# 9345    47                                        1
# 4327    33                                        1
# 774     23                                        0
#
#        Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 4799                                      1       BEAUTY PARLOUR
# 6401                                      0          STOREKEEPER
# 4245                                      1          STOREKEEPER
# 5515                                      1               VENDOR
# ...

# %%
ordinal_label = {k : i for i, k in enumerate(x_train['Sector of livelihood'].unique(),0)}
x_train['Sector of livelihood'] = x_train['Sector of livelihood'].map(ordinal_label)
# Out:
# <ipython-input-102-a3218d5e2c31>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train['Sector of livelihood'] = x_train['Sector of livelihood'].map(ordinal_label)

# %%
ordinal_label2 = {l : j for j, l in enumerate(x_train['Purpose of credit'].unique(),0)}
x_train['Purpose of credit'] = x_train['Purpose of credit'].map(ordinal_label2)
# Out:
# <ipython-input-103-97c7294322bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_train['Purpose of credit'] = x_train['Purpose of credit'].map(ordinal_label2)

# %%
ordinal_label = {k : i for i, k in enumerate(x_test['Sector of livelihood'].unique(),0)}
x_test['Sector of livelihood'] = x_test['Sector of livelihood'].map(ordinal_label)
# Out:
# <ipython-input-104-b4153d0c8615>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['Sector of livelihood'] = x_test['Sector of livelihood'].map(ordinal_label)

# %%
ordinal_label2 = {l : j for j, l in enumerate(x_test['Purpose of credit'].unique(),0)}
x_test['Purpose of credit'] = x_test['Purpose of credit'].map(ordinal_label2)
# Out:
# <ipython-input-105-054ab3fc4660>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_test['Purpose of credit'] = x_test['Purpose of credit'].map(ordinal_label2)

# %%
x_train
# Out:
#        Age  Educational level - literate/Illiterate  \
# 10263   52                                        0
# 8027    43                                        1
# 6424    38                                        1
# 3808    32                                        0
# 7093    40                                        1
# ...    ...                                      ...
# 10088   51                                        1
# 2172    28                                        0
# 9281    47                                        0
# 768     23                                        0
# 10308   52                                        0
#
#        Nature of livelihood - Farm/Non Farm  Sector of livelihood  \
# 10263                                     1                     0
# 8027                                      1                     1
# 6424                                      1                     2
# 3808                                      0                     3
# ...

# %%
x_test
# Out:
#        Age  Educational level - literate/Illiterate  \
# 4799    34                                        1
# 6401    38                                        1
# 4245    33                                        1
# 5515    36                                        1
# 10316   52                                        0
# ...    ...                                      ...
# 2441    28                                        1
# 10617   56                                        1
# 9345    47                                        1
# 4327    33                                        1
# 774     23                                        0
#
#        Nature of livelihood - Farm/Non Farm  Sector of livelihood  \
# 4799                                      1                     0
# 6401                                      0                     1
# 4245                                      1                     1
# 5515                                      1                     2
# ...

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
y = y.reshape(len(y),1)

# %%
x_train.shape
# Out:
# (8596, 10)

# %%
y_train.shape
# Out:
# (8596,)

# %%
n = pd.DataFrame(y_train)

# %%
n.head()
# Out:
#    0
# 0  1
# 1  1
# 2  0
# 3  1
# 4  0

# %%
n.shape
# Out:
# (8596, 1)

# %%
m = pd.DataFrame(x_train)

# %%
m.head()
# Out:
#        Age  Educational level - literate/Illiterate  \
# 10263   52                                        0
# 8027    43                                        1
# 6424    38                                        1
# 3808    32                                        0
# 7093    40                                        1
#
#        Nature of livelihood - Farm/Non Farm  Sector of livelihood  \
# 10263                                     1                     0
# 8027                                      1                     1
# 6424                                      1                     2
# 3808                                      0                     3
# 7093                                      1                     4
#
#        No of years of affiliation with SHG  Amount of Arrear (Non-Repayment)   \
# 10263                                    1                                  0
# 8027                                     1                                  0
# ...

# %%
m.shape
# Out:
# (8596, 10)

# %%
df = pd.concat([m, n], axis=1)

# %%
df.rename(columns = {'0':'Paid /Non Paid (Default)'}, inplace = True)

# %%
df.head()
# Out:
#     Age  Educational level - literate/Illiterate  \
# 0  18.0                                      1.0
# 1  18.0                                      0.0
# 2  18.0                                      0.0
# 3   NaN                                      NaN
# 4  18.0                                      1.0
#
#    Nature of livelihood - Farm/Non Farm  Sector of livelihood  \
# 0                                   1.0                   8.0
# 1                                   0.0                   3.0
# 2                                   1.0                   7.0
# 3                                   NaN                   NaN
# 4                                   1.0                   4.0
#
#    No of years of affiliation with SHG  Amount of Arrear (Non-Repayment)   \
# 0                                  1.0                                0.0
# 1                                  1.0                             1668.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dt.head()
# Out:
#    Age Educational level - literate/Illiterate  Monthly Income  \
# 0   18                               Literate            15900
# 1   18                             Illiterate            15000
# 2   18                             Illiterate            19630
# 3   18                             Illiterate            12000
# 4   18                               Literate            15000
#
#   Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                             Non-Farm          CONSTRUCTOR
# 1                                 FARM                DAIRY
# 2                             Non-Farm               TAILOR
# 3                                 FARM              BUFFALO
# 4                             Non-Farm          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
corr = df.corr()
fig, ax = plt.subplots(figsize = (12,10))
sns.heatmap(corr, annot=True, ax=ax, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
from sklearn.linear_model import LogisticRegression
c1 = LogisticRegression(random_state=0)
c1.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y_pred = c1.predict(x_test)
y_pred_train = c1.predict(x_train)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9837209302325581 0.9834806886924151

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(c1, x_test, y_test, cmap='Blues', values_format='.3g')

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(c1, x_train, y_train, cmap='Blues', values_format='.3g')

# %%
from xgboost import XGBClassifier
c7 = XGBClassifier()
c7.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [15:29:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'multi:softprob' was changed from 'merror' to 'mlogloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
# ...

# %%
y_pred = c7.predict(x_test)
y_pred_train = c7.predict(x_train)
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9832558139534884 0.9891810144253141

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(c7, x_train, y_train, cmap='Blues', values_format='.3g')

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(c7, x_test, y_test, cmap='Blues', values_format='.3g')

# %%
from sklearn.ensemble import RandomForestClassifier
c6 = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)
c6.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = c6.predict(x_test)
y_pred_train = c6.predict(x_train)
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9818604651162791 0.9917403443462075

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator=c6, X=x_train, y=y_train, cv=10)

# %%
print("Accuracy : {}%".format(accuracies.mean()*100))
# Out:
# Accuracy : 97.98746514335217%

# %%
cm
# Out:
# array([[ 432,    0,    0],
#        [   0, 1679,    4],
#        [   0,   35,    0]], dtype=int64)

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(c6, x_train, y_train, cmap='Blues', values_format='.3g')

# %%
from sklearn.metrics import plot_confusion_matrix
disp = plot_confusion_matrix(c6, x_test, y_test, cmap='Blues', values_format='.3g')
