# %%
import pandas as pd

# %%
dt = pd.read_csv('vedika_final.csv')

# %%
dt.head()
# Out:
#    Unnamed: 0  SI No  Member No  Age  Gender Marital status  \
# 0           0      1  100022221   18  Female        Married
# 1           1      2  170022804   18  Female        Married
# 2           2      3  220022202   18  Female        Married
# 3           3      4  220022758   18  Female        Married
# 4           4      5  280022111   18  Female        Married
#
#   Educational level - literate/Illiterate  \
# 0                               Literate
# 1                             Illiterate
# 2                             Illiterate
# 3                             Illiterate
# 4                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
# ...

# %%
dt.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10746 entries, 0 to 10745
# Data columns (total 20 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   SI No                                                            10746 non-null  int64
#  1   Member No                                                        10746 non-null  int64
#  2   Age                                                              10746 non-null  int64
#  3   Gender                                                           10746 non-null  object
#  4   Marital status                                                   10746 non-null  object
#  5   Educational level - literate/Illiterate                          10746 non-null  object
#  6   Employment status - Temporary/Permanent or Employed/Unemployed   10746 non-null  object
# ...

# %%
dt.head()
# Out:
#    SI No  Member No  Age  Gender Marital status  \
# 0      1  100022221   18  Female        Married
# 1      2  170022804   18  Female        Married
# 2      3  220022202   18  Female        Married
# 3      4  220022758   18  Female        Married
# 4      5  280022111   18  Female        Married
#
#   Educational level - literate/Illiterate  \
# 0                               Literate
# 1                             Illiterate
# 2                             Illiterate
# 3                             Illiterate
# 4                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
#    Monthly Income Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# ...

# %% [markdown]
# #Age Analysis

# %%
dt.drop(['Member No'], axis = 1, inplace = True)

# %%
dt.drop(['SI No'], axis = 1, inplace = True)

# %%
dt['Age'].mean()
# Out:
# 36.171133445002795

# %%
dt['Age'].median()
# Out:
# 36.0

# %%
dt['Age'].plot.box(grid = True)
# Out:
# <AxesSubplot:>

# %%
dt['Age'].isna().sum()
# Out:
# 0

# %%
import numpy as np

# %%
bins = np.linspace(15,60,4)

# %%
labels = ['young', 'mid-age', 'elderly']

# %%
bins
# Out:
# array([15., 30., 45., 60.])

# %%
dt['age_grp'] = pd.cut(dt['Age'], bins=bins, labels=labels, include_lowest=True)

# %%
dt.head()
# Out:
#    Age  Gender Marital status Educational level - literate/Illiterate  \
# 0   18  Female        Married                               Literate
# 1   18  Female        Married                             Illiterate
# 2   18  Female        Married                             Illiterate
# 3   18  Female        Married                             Illiterate
# 4   18  Female        Married                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
#    Monthly Income Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0           15900                             Non-Farm          CONSTRUCTOR
# ...

# %%
dt.head()
# Out:
#    Age  Gender Marital status Educational level - literate/Illiterate  \
# 0   18  Female        Married                               Literate
# 1   18  Female        Married                             Illiterate
# 2   18  Female        Married                             Illiterate
# 3   18  Female        Married                             Illiterate
# 4   18  Female        Married                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
#    Monthly Income Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0           15900                             Non-Farm          CONSTRUCTOR
# ...

# %%
dt['Gender'].value_counts()
# Out:
# Female    10746
# Name: Gender, dtype: int64

# %%
dt['Marital status'].value_counts()
# Out:
# Married    10746
# Name: Marital status, dtype: int64

# %%
dt.drop(['Gender', 'Marital status'], axis = 1, inplace = True)

# %%
dt.head()
# Out:
#    Age Educational level - literate/Illiterate  \
# 0   18                               Literate
# 1   18                             Illiterate
# 2   18                             Illiterate
# 3   18                             Illiterate
# 4   18                               Literate
#
#   Employment status - Temporary/Permanent or Employed/Unemployed   \
# 0                                      Self Employee
# 1                                      Self Employee
# 2                                      Self Employee
# 3                                      Self Employee
# 4                                      Self Employee
#
#    Monthly Income Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0           15900                             Non-Farm          CONSTRUCTOR
# 1           15000                                 FARM                DAIRY
# 2           19630                             Non-Farm               TAILOR
# ...

# %%
dt['Employment status - Temporary/Permanent or Employed/Unemployed '].value_counts()
# Out:
# Self Employee    10746
# Name: Employment status - Temporary/Permanent or Employed/Unemployed , dtype: int64

# %%
dt.drop(['Employment status - Temporary/Permanent or Employed/Unemployed '], axis = 1, inplace = True)

# %%
dt['Nature of livelihood - Farm/Non Farm'].value_counts()
# Out:
# Non-Farm    9185
# FARM        1561
# Name: Nature of livelihood - Farm/Non Farm, dtype: int64

# %%
dt['Sector of livelihood'].value_counts()
# Out:
# STOREKEEPER       2691
# GROCERY VENDOR    1855
# DAIRY             1001
# BUSINESS           926
# GARMENTS           874
# TAILOR             836
# CARPENTER          294
# CONSTRUCTOR        280
# HOTEL              271
# VENDOR             252
# BUFFALO            225
# FARMING            196
# BEAUTY PARLOUR     163
# JWELLER             94
# DRIVER              91
# WELDING             73
# GARAGE              72
# PAINTER             41
# MEAT SHOP           38
# SALOON              27
# TRANSPORT           26
# LABOUR              24
# COACHING            17
# PLUMBER             15
# BLACKSMITH          13
# FACTORY             11
# MARBLE              11
# LAUNDRY             10
# PAPAD                7
# GOLDSMITH            7
# BAMBOO               5
# TEACHER              5
# Name: Sector of livelihood, dtype: int64

# %%
dt['Sector of livelihood'].isna().sum()
# Out:
# 295

# %%
dt['Sector of livelihood'].fillna(method = 'ffill', inplace = True)

# %%
dt.isna().sum()
# Out:
# Age                                                0
# Educational level - literate/Illiterate            0
# Monthly Income                                     0
# Nature of livelihood - Farm/Non Farm               0
# Sector of livelihood                               0
# No of years of affiliation with SHG                0
# No of Family Members                               0
# Spouse Employment  status - Employed/unemployed    0
# Amount of Arrear (Non-Repayment)                   0
# No of dependent family members                     0
# Amount of credit                                   0
# Purpose of credit                                  0
# Duration of credit                                 0
# Rate of Interest                                   0
# Paid /Non Paid (Default)                           0
# age_grp                                            0
# dtype: int64

# %%
dt['Purpose of credit'].value_counts()
# Out:
# VEGITABLE          1266
# TAILORING           836
# CLOTH               644
# COW                 631
# BUISENESS           549
#                    ...
# COACHING CENTRE       1
# GHEE                  1
# COMPUTER SHOP         1
# FARI BUSS             1
# TRAVELLING            1
# Name: Purpose of credit, Length: 161, dtype: int64

# %%
dt.head()
# Out:
#    Age Educational level - literate/Illiterate  Monthly Income  \
# 0   18                               Literate            15900
# 1   18                             Illiterate            15000
# 2   18                             Illiterate            19630
# 3   18                             Illiterate            12000
# 4   18                               Literate            15000
#
#   Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                             Non-Farm          CONSTRUCTOR
# 1                                 FARM                DAIRY
# 2                             Non-Farm               TAILOR
# 3                                 FARM              BUFFALO
# 4                             Non-Farm          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
dt.drop(['Spouse Employment  status - Employed/unemployed','Duration of credit'], axis = 1, inplace = True)

# %%
dt.head()
# Out:
#    Age Educational level - literate/Illiterate  Monthly Income  \
# 0   18                               Literate            15900
# 1   18                             Illiterate            15000
# 2   18                             Illiterate            19630
# 3   18                             Illiterate            12000
# 4   18                               Literate            15000
#
#   Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                             Non-Farm          CONSTRUCTOR
# 1                                 FARM                DAIRY
# 2                             Non-Farm               TAILOR
# 3                                 FARM              BUFFALO
# 4                             Non-Farm          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
dt['Educational level - literate/Illiterate'] = le.fit_transform(dt['Educational level - literate/Illiterate'])

# %%
le2 = LabelEncoder()
dt['Nature of livelihood - Farm/Non Farm'] = le2.fit_transform(dt['Nature of livelihood - Farm/Non Farm'])

# %%
min_val = dt['Amount of credit'].min()
max_val = dt['Amount of credit'].max()
maxmin = max_val - min_val
for i in range(len(dt['Amount of credit'])):
    dt['Amount of credit'][i] = (dt['Amount of credit'][i] - min_val)/maxmin
# Out:
# <ipython-input-38-0c467ff36135>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt['Amount of credit'][i] = (dt['Amount of credit'][i] - min_val)/maxmin

# %%
dt.head()
# Out:
#    Age  Educational level - literate/Illiterate  Monthly Income  \
# 0   18                                        1           15900
# 1   18                                        0           15000
# 2   18                                        0           19630
# 3   18                                        0           12000
# 4   18                                        1           15000
#
#    Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                                     1          CONSTRUCTOR
# 1                                     0                DAIRY
# 2                                     1               TAILOR
# 3                                     0              BUFFALO
# 4                                     1          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
min_val1 = dt['Rate of Interest'].min()
max_val1 = dt['Rate of Interest'].max()
maxmin1 = max_val1 - min_val1
for i in range(len(dt['Rate of Interest'])):
    dt['Rate of Interest'][i] = (dt['Rate of Interest'][i] - min_val1)/maxmin1
# Out:
# <ipython-input-40-9748f89bfd2a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt['Rate of Interest'][i] = (dt['Rate of Interest'][i] - min_val1)/maxmin1

# %%
dt.head()
# Out:
#    Age  Educational level - literate/Illiterate  Monthly Income  \
# 0   18                                        1           15900
# 1   18                                        0           15000
# 2   18                                        0           19630
# 3   18                                        0           12000
# 4   18                                        1           15000
#
#    Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                                     1          CONSTRUCTOR
# 1                                     0                DAIRY
# 2                                     1               TAILOR
# 3                                     0              BUFFALO
# 4                                     1          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
dt_2 = dt.drop(['Sector of livelihood', 'Purpose of credit', 'Paid /Non Paid (Default)'], axis = 1)
y = dt['Paid /Non Paid (Default)']

# %%
le3 = LabelEncoder()
dt['Paid /Non Paid (Default)'] = le3.fit_transform(dt['Paid /Non Paid (Default)'])

# %%
corr_matrix = dt.corr()
corr_matrix['Paid /Non Paid (Default)'].sort_values(ascending=False)
# Out:
# Paid /Non Paid (Default)                   1.000000
# Age                                        0.024001
# Monthly Income                             0.014116
# Educational level - literate/Illiterate    0.003200
# Rate of Interest                           0.002144
# Amount of credit                          -0.002144
# No of Family Members                      -0.003065
# No of dependent family members            -0.003065
# No of years of affiliation with SHG       -0.012721
# Nature of livelihood - Farm/Non Farm      -0.027912
# Amount of Arrear (Non-Repayment)          -0.709018
# Name: Paid /Non Paid (Default), dtype: float64

# %%
dt_2.head()
# Out:
#    Age  Educational level - literate/Illiterate  Monthly Income  \
# 0   18                                        1           15900
# 1   18                                        0           15000
# 2   18                                        0           19630
# 3   18                                        0           12000
# 4   18                                        1           15000
#
#    Nature of livelihood - Farm/Non Farm  No of years of affiliation with SHG  \
# 0                                     1                                    1
# 1                                     0                                    1
# 2                                     1                                    1
# 3                                     0                                    1
# 4                                     1                                    1
#
#    No of Family Members  Amount of Arrear (Non-Repayment)   \
# ...

# %%
x = dt.drop(['age_grp', 'No of dependent family members', 'Paid /Non Paid (Default)'], axis = 1)

# %%
x.head()
# Out:
#    Age  Educational level - literate/Illiterate  Monthly Income  \
# 0   18                                        1           15900
# 1   18                                        0           15000
# 2   18                                        0           19630
# 3   18                                        0           12000
# 4   18                                        1           15000
#
#    Nature of livelihood - Farm/Non Farm Sector of livelihood  \
# 0                                     1          CONSTRUCTOR
# 1                                     0                DAIRY
# 2                                     1               TAILOR
# 3                                     0              BUFFALO
# 4                                     1          STOREKEEPER
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
ordinal_label = {k : i for i, k in enumerate(x['Sector of livelihood'].unique(),0)}
x['Sector of livelihood'] = x['Sector of livelihood'].map(ordinal_label)

# %%
ordinal_label2 = {l : j for j, l in enumerate(x['Purpose of credit'].unique(),0)}
x['Purpose of credit'] = x['Purpose of credit'].map(ordinal_label2)

# %%
x.head()
# Out:
#    Age  Educational level - literate/Illiterate  Monthly Income  \
# 0   18                                        1           15900
# 1   18                                        0           15000
# 2   18                                        0           19630
# 3   18                                        0           12000
# 4   18                                        1           15000
#
#    Nature of livelihood - Farm/Non Farm  Sector of livelihood  \
# 0                                     1                     0
# 1                                     0                     1
# 2                                     1                     2
# 3                                     0                     3
# 4                                     1                     4
#
#    No of years of affiliation with SHG  No of Family Members  \
# 0                                    1                     4
# 1                                    1                     4
# ...

# %%
x['Purpose of credit'].isna().sum()
# Out:
# 0

# %%
from sklearn.feature_selection import chi2
fpvalue = chi2(x,y)
fpvalue
# Out:
# (array([1.77679247e+01, 8.38420556e-02, 4.90948272e+03, 1.22418770e+00,
#         2.04684665e+01, 1.99922569e-01, 3.60434018e-02, 7.83883310e+07,
#         7.27220257e-02, 1.17949800e+01, 1.34071012e-01]),
#  array([1.38593922e-04, 9.58945508e-01, 0.00000000e+00, 5.42214364e-01,
#         3.59193916e-05, 9.04872450e-01, 9.82139719e-01, 0.00000000e+00,
#         9.64292109e-01, 2.74632943e-03, 9.35161997e-01]))

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
le4 = LabelEncoder()
y = le4.fit_transform(y)

# %%
y
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
y = y.reshape(len(y), 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
c1 = LogisticRegression(random_state=0)
c1.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# LogisticRegression(random_state=0)

# %%
y_pred = c1.predict(x_test)

# %%
y_pred_train = c1.predict(x_train)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)

# %%
print(acc1, acc2)
# Out:
# 0.9725581395348837 0.9705677059097254

# %%
from sklearn.svm import SVC
c2 = SVC(kernel = 'rbf', random_state = 0)
c2.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVC(random_state=0)

# %%
y_pred = c2.predict(x_test)
y_pred_train = c1.predict(x_train)

# %%
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9641860465116279 0.9705677059097254

# %%
from sklearn.tree import DecisionTreeClassifier
c3 = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
c3.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = c3.predict(x_test)
y_pred_train = c3.predict(x_train)
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9758139534883721 0.991042345276873

# %%
from sklearn.neighbors import KNeighborsClassifier
c4 = KNeighborsClassifier(n_neighbors=3, metric='minkowski', p=2)
c4.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\sklearn\neighbors\_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = c4.predict(x_test)
y_pred_train = c4.predict(x_train)
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9395348837209302 0.9545137273150303

# %%
from sklearn.naive_bayes import GaussianNB
c5 = GaussianNB()
c5.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# GaussianNB()

# %%
y_pred = c5.predict(x_test)
y_pred_train = c5.predict(x_train)
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9693023255813954 0.9701023731968358

# %%
from sklearn.ensemble import RandomForestClassifier
c6 = RandomForestClassifier(n_estimators=10, criterion='entropy', random_state=0)
c6.fit(x_train, y_train)
# Out:
# <ipython-input-91-e75c28e4db77>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   c6.fit(x_train, y_train)
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = c6.predict(x_test)
y_pred_train = c6.predict(x_train)
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9809302325581395 0.9889483480688692

# %%
# !pip install xgboost

# %%
from xgboost import XGBClassifier
c7 = XGBClassifier()
c7.fit(x_train, y_train)
# Out:
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\Asus\Desktop\Anaconda\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
y_pred = c7.predict(x_test)
y_pred_train = c7.predict(x_train)
cm = confusion_matrix(y_test, y_pred)
cm2 = confusion_matrix(y_train, y_pred_train)
acc1 = accuracy_score(y_test, y_pred)
acc2 = accuracy_score(y_train, y_pred_train)
print(acc1, acc2)
# Out:
# 0.9818604651162791 0.9879013494648674
